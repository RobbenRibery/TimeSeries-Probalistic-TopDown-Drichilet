# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.insert(0, '../src/')
import pandas as pd 
import numpy as np 
from utils import * 
from hts.hierarchy import HierarchyTree 
from datetime import datetime 
import torch 
from proption_model import *

# %%
sales_train_validation = pd.read_csv('../data/sales_train_validation.csv')
sales_train_evaluation = pd.read_csv('../data/sales_train_evaluation.csv') 
calender = pd.read_csv('../data/calendar.csv') 
date_to_d = dict(zip(calender.date, calender.d)) 
d_to_date = dict(zip(calender.d, calender.date))

# %% [markdown]
# ## Parent nodes sales

# %%
parent_sales = sales_train_validation[sales_train_validation.columns[6:]].sum(axis=0).values
print(parent_sales.shape)
# Out:
# (1913,)

# %% [markdown]
# ## Hie EDA

# %%
sales_train_evaluation.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  d_1935  d_1936  \
# 0       CA    0    0    0    0  ...       2       4       0       0       0
# 1       CA    0    0    0    0  ...       0       1       2       1       1
# 2       CA    0    0    0    0  ...       1       0       2       0       0
# 3       CA    0    0    0    0  ...       1       1       0       4       0
# 4       CA    0    0    0    0  ...       0       0       0       2       1
#
#    d_1937  d_1938  d_1939  d_1940  d_1941
# 0       0       3       3       0       1
# 1       0       0       0       0       0
# 2       0       2       3       0       1
# 3       1       3       0       2       6
# 4       0       0       2       1       0
#
# [5 rows x 1947 columns]

# %%
print(sales_train_evaluation.shape)
print(sales_train_evaluation.columns[:6])
# Out:
# (30490, 1947)
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], dtype='object')

# %%
groupby_list = ['state_id','store_id','cat_id','dept_id','item_id']

# %% [markdown]
# - Fully encoded hierachy

# %%
hierachy_lookup = sales_train_evaluation.groupby(groupby_list[:]).count()[['id']]
hierachy_lookup
# Out:
#                                                          id
# state_id store_id cat_id    dept_id     item_id
# CA       CA_1     FOODS     FOODS_1     FOODS_1_001       1
#                                         FOODS_1_002       1
#                                         FOODS_1_003       1
#                                         FOODS_1_004       1
#                                         FOODS_1_005       1
# ...                                                      ..
# WI       WI_3     HOUSEHOLD HOUSEHOLD_2 HOUSEHOLD_2_512   1
#                                         HOUSEHOLD_2_513   1
#                                         HOUSEHOLD_2_514   1
#                                         HOUSEHOLD_2_515   1
#                                         HOUSEHOLD_2_516   1
#
# [30490 rows x 1 columns]

# %%
#hierachy_lookup.loc[('CA','CA_1','FOODS','FOODS_1')].index.to_list()

# %% [markdown]
# - Partially encoded hierachy

# %%
hierachy_lookup_2 = sales_train_evaluation.groupby(groupby_list[2:]).count()[['id']]
hierachy_lookup_2.head()
# Out:
#                             id
# cat_id dept_id item_id
# FOODS  FOODS_1 FOODS_1_001  10
#                FOODS_1_002  10
#                FOODS_1_003  10
#                FOODS_1_004  10
#                FOODS_1_005  10

# %%
hierachy_lookup_2
# Out:
#                                        id
# cat_id    dept_id     item_id
# FOODS     FOODS_1     FOODS_1_001      10
#                       FOODS_1_002      10
#                       FOODS_1_003      10
#                       FOODS_1_004      10
#                       FOODS_1_005      10
# ...                                    ..
# HOUSEHOLD HOUSEHOLD_2 HOUSEHOLD_2_512  10
#                       HOUSEHOLD_2_513  10
#                       HOUSEHOLD_2_514  10
#                       HOUSEHOLD_2_515  10
#                       HOUSEHOLD_2_516  10
#
# [3049 rows x 1 columns]

# %% [markdown]
# - ## PROD CODE FOLLOWING

# %%
hl_prod = sales_train_validation.groupby(groupby_list[2:]).count()[['id']].reset_index()
hl_prod.head()
# Out:
#   cat_id  dept_id      item_id  id
# 0  FOODS  FOODS_1  FOODS_1_001  10
# 1  FOODS  FOODS_1  FOODS_1_002  10
# 2  FOODS  FOODS_1  FOODS_1_003  10
# 3  FOODS  FOODS_1  FOODS_1_004  10
# 4  FOODS  FOODS_1  FOODS_1_005  10

# %%
df_left = hl_prod
df_right = sales_train_validation.groupby('item_id').sum()
df = df_left.merge(df_right, left_on='item_id', right_index=True, how='inner').drop(columns=['id'])
df.rename(columns=d_to_date, inplace=True)

# %%
df
# Out:
#          cat_id      dept_id          item_id  2011-01-29  2011-01-30  \
# 0         FOODS      FOODS_1      FOODS_1_001           6           6
# 1         FOODS      FOODS_1      FOODS_1_002           4           5
# 2         FOODS      FOODS_1      FOODS_1_003          14           8
# 3         FOODS      FOODS_1      FOODS_1_004           0           0
# 4         FOODS      FOODS_1      FOODS_1_005          34          32
# ...         ...          ...              ...         ...         ...
# 3044  HOUSEHOLD  HOUSEHOLD_2  HOUSEHOLD_2_512           5           4
# 3045  HOUSEHOLD  HOUSEHOLD_2  HOUSEHOLD_2_513           0           0
# 3046  HOUSEHOLD  HOUSEHOLD_2  HOUSEHOLD_2_514           4           8
# 3047  HOUSEHOLD  HOUSEHOLD_2  HOUSEHOLD_2_515           0           0
# 3048  HOUSEHOLD  HOUSEHOLD_2  HOUSEHOLD_2_516           2           4
#
#       2011-01-31  2011-02-01  2011-02-02  2011-02-03  2011-02-04  ...  \
# 0              4           6           7          18          10  ...
# 1              7           4           3           4           1  ...
# 2              3           6           3           8          13  ...
# 3              0           0           0           0           0  ...
# 4             13          20          10          21          18  ...
# ...          ...         ...         ...         ...         ...  ...
# 3044           1           3           2           4           2  ...
# 3045           0           0           0           0           0  ...
# 3046           2           1           1           2           3  ...
# 3047           0           0           0           0           0  ...
# 3048           0           3           1           2           2  ...
#
#       2016-04-15  2016-04-16  2016-04-17  2016-04-18  2016-04-19  2016-04-20  \
# 0              4           4          30           7           5           3
# 1              5           9           4           1           3           5
# 2              7           3           5           6           3           4
# 3              0           0           0           0           0           0
# 4             16          14          14          18          18          27
# ...          ...         ...         ...         ...         ...         ...
# 3044           6           7           9          13          12           2
# 3045           9           3           3           3           2           4
# 3046           1           2           2           0           1           0
# 3047           1           3           2           0           0           1
# 3048           4           1           1           0           0           1
#
#       2016-04-21  2016-04-22  2016-04-23  2016-04-24
# 0              6           2          16           6
# 1              5           3           3           1
# 2              4           3          11           5
# 3              0           0           0           0
# 4             12          15          38           9
# ...          ...         ...         ...         ...
# 3044           8           6          10           5
# 3045           6           7           4          11
# 3046           0           2           2           2
# 3047           1           1           5           1
# 3048           2           1           0           1
#
# [3049 rows x 1916 columns]

# %% [markdown]
# ## Time related covariates:
#
# - Wehther it is weekend/not, we observed sales are high overweekend across three categories

# %%
date = [d_to_date[d] for d in sales_train_validation.columns[6:]]

# %%
print(f'The statrting date is {date[0]}')
print(f'The statrting date is {date[-1]}')
# Out:
# The statrting date is 2011-01-29
# The statrting date is 2016-04-24

# %%
d = datetime.strptime(date[2], '%Y-%m-%d')
if d.weekday() > 4:
    print ('Given date is weekend.')
else:
    print ('Given data is weekday.')
# Out:
# Given data is weekday.

# %%
d.weekday()
# Out:
# 0

# %%
weekend_binary = [1 if (datetime.strptime(d, '%Y-%m-%d')).weekday() > 4 else 0 for d in date]
print(len(weekend_binary))
# Out:
# 1913

# %% [markdown]
# ## Proportions

# %%
stv = sales_train_validation[sales_train_validation.columns[6:]]
stv = stv.T
print(stv.shape)
# Out:
# (1913, 30490)

# %%
len(stv.sum(axis=1).values)
# Out:
# 1913

# %% [markdown]
# ## Time series embeddings

# %%
hie_index = torch.arange(stv.shape[1])

hie_index_2d = hie_index.expand(stv.shape[0], stv.shape[1])

hie_index_3d = hie_index_2d.reshape(
    hie_index_2d.shape[0], hie_index_2d.shape[-1], 1
)

print(hie_index_3d.shape)
# Out:
# torch.Size([1913, 30490, 1])

# %%
stv_proportions = np.divide(stv.values, stv.sum(axis=1).values.reshape(-1,1))
print(stv_proportions.sum(axis=1).sum())

stv_proportions_3d = stv_proportions.reshape(stv_proportions.shape[0], stv_proportions.shape[1], 1)
print(stv_proportions_3d.shape)

proportions_tensor = torch.tensor(stv_proportions_3d)
print(proportions_tensor.shape)
# Out:
# 1913.0
# (1913, 30490, 1)
# torch.Size([1913, 30490, 1])

# %%
weekend_binary_tensor = torch.tensor(weekend_binary).unsqueeze_(-1).unsqueeze_(-1)
weekend_binary_tensor = weekend_binary_tensor.expand(stv_proportions.shape[0], stv_proportions.shape[1], weekend_binary_tensor.shape[-1])
print(weekend_binary_tensor.shape)
print(weekend_binary_tensor[1,0])
print(weekend_binary_tensor[2,0])
# Out:
# torch.Size([1913, 30490, 1])
# tensor([1])
# tensor([0])

# %%
parent_sales_tensor = torch.tensor(parent_sales).unsqueeze_(-1).unsqueeze_(-1)
parent_sales_tensor = parent_sales_tensor.expand(stv_proportions.shape[0], stv_proportions.shape[1], parent_sales_tensor.shape[-1])
print(parent_sales_tensor.shape)
# Out:
# torch.Size([1913, 30490, 1])

# %%
data_3d = torch.cat((proportions_tensor, parent_sales_tensor,weekend_binary_tensor, hie_index_3d), -1)
data_3d = data_3d.double()
print(data_3d.shape)
# Out:
# torch.Size([1913, 30490, 4])

# %%
# dimension about the dataset
no_child = proportions_tensor.shape[1]
History = 28
Forward = 28

number_observations = data_3d.shape[0] - (History + Forward) + 1

data_3d_time_batched = torch.empty(
    number_observations, History + Forward, data_3d.shape[1], data_3d.shape[2]
)

for i in range(number_observations):

    data_3d_time_batched[i, :, :, :] = data_3d[i : i + History + Forward, :, :]

print(data_3d_time_batched.shape)
print(data_3d_time_batched[-1,:,:,:].shape)


#if torch.equal(data_3d_time_batched[-1, -1, :, :].double(), data_3d[-1, :, :].double()):

print("data correctly processed to generate time-bacted tensor")

input_tensor = torch.empty(
    number_observations,
    History,
    data_3d_time_batched.shape[-2],
    data_3d_time_batched.shape[-1],
)

## We first use the recursive predicitng mechanism in LSTM, in the future we release more blocks that adapt to teacher-forcing/mixed training
target_tensor = torch.empty(
    number_observations,
    Forward,
    data_3d_time_batched.shape[-2],
    1
    # data_3d_time_batched.shape[-1]
)

print(input_tensor.shape)
print(target_tensor.shape)

print("Entering the training pipeline")

for i in range(data_3d_time_batched.shape[0]):

    input_tensor[i] = data_3d_time_batched[i, :History, :, :]
    target_2d = data_3d_time_batched[i, History:, :, 0]
    target_tensor[i] = target_2d.reshape(
        target_2d.shape[0], target_2d.shape[1], 1
    )

    # print(input_tensor.shape)
    # print(target_tensor.shape)

print(input_tensor.shape)
print(target_tensor.shape)
    # print(target_tensor[-1,0,:,:].sum())
# Out:
# torch.Size([1858, 56, 30490, 4])
# torch.Size([56, 30490, 4])
# data correctly processed to generate time-bacted tensor
# torch.Size([1858, 28, 30490, 4])
# torch.Size([1858, 28, 30490, 1])
# Entering the training pipeline
# torch.Size([1858, 28, 30490, 4])
# torch.Size([1858, 28, 30490, 1])

# %%
###---------- dimension on the model hypter-parameters from the paper ------------ ######
num_hts_embedd = no_child
hts_embedd_dim = 8
covariate_dim = 2 

lstm_input_dim = 2 + covariate_dim + hts_embedd_dim
lstm_hidden_dim = 48
lstm_num_layer = 1
lstm_output_dim = 64

mha_embedd_dim = lstm_output_dim
num_head = 4
num_attention_layer = 1
mha_output_dim = mha_embedd_dim
residual_output_dim = mha_output_dim
model_ouput_dim = 1

# define the model object
p_model = proportion_model(
    num_hts_embedd,
    hts_embedd_dim,  # ts embedding hyper pars
    lstm_input_dim,
    lstm_hidden_dim,
    lstm_num_layer,
    lstm_output_dim,  # lstm hyper pars
    mha_embedd_dim,
    num_head,
    num_attention_layer,  # mha hyper pars
    mha_output_dim,
    residual_output_dim,  # skip connection hyper pars
    model_ouput_dim,  # output later hyper pars
)

###---------- trainign parameters from the paper ------------ ######

n_epochs = 50
target_len = Forward
batch_size = 4
l_r = 0.00079

# start training
p_model.train(
    input_tensor,
    target_tensor,
    n_epochs,
    target_len,
    batch_size,
    learning_rate=l_r,
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ericliu/Desktop/ML-Side Project/TS Forecasting/Kaggle - M5 - Sales Forecating (accuracy)/notebook/feature_generation.ipynb Cell 21 in <cell line: 42>()
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=38'>39</a> l_r = 0.00079
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=40'>41</a> # start training
# ---> <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=41'>42</a> p_model.train(
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=42'>43</a>     input_tensor,
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=43'>44</a>     target_tensor,
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=44'>45</a>     n_epochs,
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=45'>46</a>     target_len,
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=46'>47</a>     batch_size,
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=47'>48</a>     learning_rate=l_r,
#      <a href='vscode-notebook-cell:/Users/ericliu/Desktop/ML-Side%20Project/TS%20Forecasting/Kaggle%20-%20M5%20-%20Sales%20Forecating%20%28accuracy%29/notebook/feature_generation.ipynb#ch0000028?line=48'>49</a> )
#
# File ~/Desktop/ML-Side Project/TS Forecasting/Kaggle - M5 - Sales Forecating (accuracy)/src/proption_model.py:425, in proportion_model.train(self, input_tensor, target_tensor, n_epochs, target_len, batch_size, learning_rate)
#     418 input = cat((input, embedd_vector), -1)
#     419 # print(f"with ENCODED hierachy, input batch diemsion is {input.shape}")
#     420
#     421 ## ------------ lstm encoder ---input: L, C, input_dim ---------- ##
#     422 encoder_ouput, (
#     423     encoder_hn,
#     424     encoder_cn,
# --> 425 ) = self.encoder_lstm.forward(input, h0, c0)
#     426 encoder_cache = (encoder_hn, encoder_cn)
#     427 # print(f"The encoder final hidden state shape is {encoder_hn.shape}")
#     428 # print(f"The encoder final cell state shape is {encoder_hn.shape}")
#     429
#     430 ## ------------- lstm ddecoder --------L, C, input_dim ----------- ##
#
# File ~/Desktop/ML-Side Project/TS Forecasting/Kaggle - M5 - Sales Forecating (accuracy)/src/proption_model.py:119, in encoder_lstm.forward(self, x, h0, c0)
#     108 def forward(self, x, h0, c0):
#     110     """
#     111     : param x :                    input of shape (# in batch, seq_len, lstm_input_dim)
#     112
#    (...)
#     116     :                              element in the sequence
#     117     """
# --> 119     encoder_ouptut, (self.hn, self.cn) = self.lstm(x, (h0, c0))
#     120     self.cache = (self.hn, self.cn)
#     122     return encoder_ouptut, self.cache
#
# File ~/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/rnn.py:759, in LSTM.forward(self, input, hx)
#     755     # Each batch of the hidden state should match the input sequence that
#     756     # the user believes he/she is passing in.
#     757     hx = self.permute_hidden(hx, sorted_indices)
# --> 759 self.check_forward_args(input, hx, batch_sizes)
#     760 if batch_sizes is None:
#     761     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     762                       self.dropout, self.training, self.bidirectional, self.batch_first)
#
# File ~/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/rnn.py:684, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#     679 def check_forward_args(self,  # type: ignore[override]
#     680                        input: Tensor,
#     681                        hidden: Tuple[Tensor, Tensor],
#     682                        batch_sizes: Optional[Tensor],
#     683                        ):
# --> 684     self.check_input(input, batch_sizes)
#     685     self.check_hidden_size(hidden[0], self.get_expected_hidden_size(input, batch_sizes),
#     686                            'Expected hidden[0] size {}, got {}')
#     687     self.check_hidden_size(hidden[1], self.get_expected_cell_size(input, batch_sizes),
#     688                            'Expected hidden[1] size {}, got {}')
#
# File ~/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/rnn.py:205, in RNNBase.check_input(self, input, batch_sizes)
#     201     raise RuntimeError(
#     202         'input must have {} dimensions, got {}'.format(
#     203             expected_input_dim, input.dim()))
#     204 if self.input_size != input.size(-1):
# --> 205     raise RuntimeError(
#     206         'input.size(-1) must be equal to input_size. Expected {}, got {}'.format(
#     207             self.input_size, input.size(-1)))
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 12, got 11
